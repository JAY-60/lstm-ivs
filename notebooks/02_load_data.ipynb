# %%
# 02_load_data.ipynb
# Load option/IV data and basic validation
# Author: Jay Debrah

import pandas as pd
import numpy as np
from pathlib import Path

DATA_RAW = Path("../data/raw")
DATA_INTERIM = Path("../data/interim")

print("Paths set:")
print("RAW:", DATA_RAW.resolve())
print("INTERIM:", DATA_INTERIM.resolve())
# Out:
# Paths set:
# RAW: C:\Users\junio\projects\lstm-ivs\data\raw
# INTERIM: C:\Users\junio\projects\lstm-ivs\data\interim
